# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027207103e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('loss: ', loss)
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# loss:  1.30378789133
# Difference between your loss and correct loss:
# 1.79412040779e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# b2 max relative error: 3.865070e-11
# W2 max relative error: 3.440708e-09
# b1 max relative error: 2.738421e-09
# W1 max relative error: 3.561318e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0171496079387

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.259602
# iteration 400 / 1000: loss 2.204170
# iteration 500 / 1000: loss 2.118565
# iteration 600 / 1000: loss 2.051535
# iteration 700 / 1000: loss 1.988466
# iteration 800 / 1000: loss 2.006591
# iteration 900 / 1000: loss 1.951473
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplots_adjust(hspace=0.4)
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
import itertools

learning_rates = [1e-3, 1.5e-3]
regularization_strengths = [.175, .25, .5]
batch_sizes = [200, 300, 400]
number_iterations = [1000, 1500, 2000]
hidden_sizes = [50, 75, 100]

input_size - 32 * 32 * 3
num_classes = 10

results = {}   # map of hyper-parameter values
best_val = -1  # the best validation accuracy

for [lr, rs, bs, ni, hs] in itertools.product(learning_rates, regularization_strengths, batch_sizes, number_iterations
                                             , hidden_sizes):
    
    net = TwoLayerNet(input_size, hs, num_classes)
                                              
    # Train the network
    stats = net.train(X_train, y_train, X_val, y_val,
                num_iters=ni, batch_size=bs,
                learning_rate=lr, learning_rate_decay=0.95,
                reg=rs, verbose=True)
    
    # Predict on the training set
    training_accuracy = (net.predict(X_train) == y_train).mean()
    
    # Predict on the validation set
    validation_accuracy = (net.predict(X_val) == y_val).mean() 
    
    print('lr %e rs %f bs %d ni %d hs %d train accuracy %f val accuracy %f' % (lr, rs, bs, ni, hs, 
                                                                                         training_accuracy,
                                                                                         validation_accuracy))                                         
   
    results[(lr, rs, bs, ni, hs)] = (training_accuracy, validation_accuracy) 
    
    if (validation_accuracy > best_val):
        best_val = validation_accuracy
        best_net = net
    
# Print out results.
for lr, rs, bs, ni, hs in sorted(results):
    train_accuracy, val_accuracy = results[(lr, rs, bs, ni, hs)]
    print('lr %e rs %f bs %d ni %d hs %d train accuracy: %f val accuracy: %f' % (
                lr, rs, bs, ni, hs, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)

#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# iteration 0 / 1000: loss 2.302876
# iteration 100 / 1000: loss 1.901238
# iteration 200 / 1000: loss 1.744360
# iteration 300 / 1000: loss 1.611569
# iteration 400 / 1000: loss 1.587698
# iteration 500 / 1000: loss 1.518606
# iteration 600 / 1000: loss 1.564793
# iteration 700 / 1000: loss 1.546016
# iteration 800 / 1000: loss 1.462350
# iteration 900 / 1000: loss 1.479945
# lr 1.000000e-03 rs 0.175000 bs 200 ni 1000 hs 50 train accuracy 0.492347 val accuracy 0.461000
# iteration 0 / 1000: loss 2.302969
# iteration 100 / 1000: loss 1.889808
# iteration 200 / 1000: loss 1.732051
# iteration 300 / 1000: loss 1.611586
# iteration 400 / 1000: loss 1.545296
# iteration 500 / 1000: loss 1.546668
# iteration 600 / 1000: loss 1.514942
# iteration 700 / 1000: loss 1.651485
# iteration 800 / 1000: loss 1.518653
# iteration 900 / 1000: loss 1.487214
# lr 1.000000e-03 rs 0.175000 bs 200 ni 1000 hs 75 train accuracy 0.491265 val accuracy 0.471000
# iteration 0 / 1000: loss 2.303097
# iteration 100 / 1000: loss 1.890877
# iteration 200 / 1000: loss 1.728019
# iteration 300 / 1000: loss 1.742934
# iteration 400 / 1000: loss 1.531715
# iteration 500 / 1000: loss 1.639471
# iteration 600 / 1000: loss 1.592288
# iteration 700 / 1000: loss 1.559851
# iteration 800 / 1000: loss 1.465795
# iteration 900 / 1000: loss 1.595123
# lr 1.000000e-03 rs 0.175000 bs 200 ni 1000 hs 100 train accuracy 0.499286 val accuracy 0.472000
# iteration 0 / 1500: loss 2.302860
# iteration 100 / 1500: loss 1.945689
# iteration 200 / 1500: loss 1.780404
# iteration 300 / 1500: loss 1.705543
# iteration 400 / 1500: loss 1.619439
# iteration 500 / 1500: loss 1.529352
# iteration 600 / 1500: loss 1.617205
# iteration 700 / 1500: loss 1.496235
# iteration 800 / 1500: loss 1.501988
# iteration 900 / 1500: loss 1.567048
# iteration 1000 / 1500: loss 1.336541
# iteration 1100 / 1500: loss 1.557641
# iteration 1200 / 1500: loss 1.428068
# iteration 1300 / 1500: loss 1.360470
# iteration 1400 / 1500: loss 1.534770
# lr 1.000000e-03 rs 0.175000 bs 200 ni 1500 hs 50 train accuracy 0.513694 val accuracy 0.474000
# iteration 0 / 1500: loss 2.302998
# iteration 100 / 1500: loss 1.852878
# iteration 200 / 1500: loss 1.785916
# iteration 300 / 1500: loss 1.581466
# iteration 400 / 1500: loss 1.650832
# iteration 500 / 1500: loss 1.604924
# iteration 600 / 1500: loss 1.558056
# iteration 700 / 1500: loss 1.471350
# iteration 800 / 1500: loss 1.560923
# iteration 900 / 1500: loss 1.557065
# iteration 1000 / 1500: loss 1.330047
# iteration 1100 / 1500: loss 1.496194
# iteration 1200 / 1500: loss 1.404855
# iteration 1300 / 1500: loss 1.402852
# iteration 1400 / 1500: loss 1.374913
# lr 1.000000e-03 rs 0.175000 bs 200 ni 1500 hs 75 train accuracy 0.520531 val accuracy 0.487000
# iteration 0 / 1500: loss 2.303120
# iteration 100 / 1500: loss 1.840241
# iteration 200 / 1500: loss 1.699466
# iteration 300 / 1500: loss 1.668000
# iteration 400 / 1500: loss 1.805178
# iteration 500 / 1500: loss 1.743781
# iteration 600 / 1500: loss 1.511819
# iteration 700 / 1500: loss 1.425115
# iteration 800 / 1500: loss 1.409196
# iteration 900 / 1500: loss 1.459780
# iteration 1000 / 1500: loss 1.388379
# iteration 1100 / 1500: loss 1.313599
# iteration 1200 / 1500: loss 1.439710
# iteration 1300 / 1500: loss 1.435563
# iteration 1400 / 1500: loss 1.528436
# lr 1.000000e-03 rs 0.175000 bs 200 ni 1500 hs 100 train accuracy 0.532020 val accuracy 0.493000
# iteration 0 / 2000: loss 2.302862
# iteration 100 / 2000: loss 1.978668
# iteration 200 / 2000: loss 1.751114
# iteration 300 / 2000: loss 1.713497
# iteration 400 / 2000: loss 1.668677
# iteration 500 / 2000: loss 1.611303
# iteration 600 / 2000: loss 1.545473
# iteration 700 / 2000: loss 1.564994
# iteration 800 / 2000: loss 1.600326
# iteration 900 / 2000: loss 1.523852
# iteration 1000 / 2000: loss 1.505457
# iteration 1100 / 2000: loss 1.574163
# iteration 1200 / 2000: loss 1.412984
# iteration 1300 / 2000: loss 1.509080
# iteration 1400 / 2000: loss 1.419408
# iteration 1500 / 2000: loss 1.505661
# iteration 1600 / 2000: loss 1.507988
# iteration 1700 / 2000: loss 1.552350
# iteration 1800 / 2000: loss 1.476506
# iteration 1900 / 2000: loss 1.317793
# lr 1.000000e-03 rs 0.175000 bs 200 ni 2000 hs 50 train accuracy 0.530878 val accuracy 0.498000
# iteration 0 / 2000: loss 2.302981
# iteration 100 / 2000: loss 1.994551
# iteration 200 / 2000: loss 1.759638
# iteration 300 / 2000: loss 1.645868
# iteration 400 / 2000: loss 1.516754
# iteration 500 / 2000: loss 1.585776
# iteration 600 / 2000: loss 1.515328
# iteration 700 / 2000: loss 1.468274
# iteration 800 / 2000: loss 1.569012
# iteration 900 / 2000: loss 1.531090
# iteration 1000 / 2000: loss 1.434537
# iteration 1100 / 2000: loss 1.416623
# iteration 1200 / 2000: loss 1.492894
# iteration 1300 / 2000: loss 1.398810
# iteration 1400 / 2000: loss 1.494046
# iteration 1500 / 2000: loss 1.399835
# iteration 1600 / 2000: loss 1.500311
# iteration 1700 / 2000: loss 1.435949
# iteration 1800 / 2000: loss 1.340388
# iteration 1900 / 2000: loss 1.373154
# lr 1.000000e-03 rs 0.175000 bs 200 ni 2000 hs 75 train accuracy 0.545633 val accuracy 0.504000
# iteration 0 / 2000: loss 2.303155
# iteration 100 / 2000: loss 1.891324
# iteration 200 / 2000: loss 1.686585
# iteration 300 / 2000: loss 1.640656
# iteration 400 / 2000: loss 1.623371
# iteration 500 / 2000: loss 1.569683
# iteration 600 / 2000: loss 1.492490
# iteration 700 / 2000: loss 1.427381
# iteration 800 / 2000: loss 1.544438
# iteration 900 / 2000: loss 1.316795
# iteration 1000 / 2000: loss 1.421339
# iteration 1100 / 2000: loss 1.335404
# iteration 1200 / 2000: loss 1.254334
# iteration 1300 / 2000: loss 1.452830
# iteration 1400 / 2000: loss 1.297363
# iteration 1500 / 2000: loss 1.247389
# iteration 1600 / 2000: loss 1.314694
# iteration 1700 / 2000: loss 1.452877
# iteration 1800 / 2000: loss 1.320082
# iteration 1900 / 2000: loss 1.360757
# lr 1.000000e-03 rs 0.175000 bs 200 ni 2000 hs 100 train accuracy 0.552837 val accuracy 0.506000
# iteration 0 / 1000: loss 2.302880
# iteration 100 / 1000: loss 1.953000
# iteration 200 / 1000: loss 1.742797
# iteration 300 / 1000: loss 1.716129
# iteration 400 / 1000: loss 1.560391
# iteration 500 / 1000: loss 1.548072
# iteration 600 / 1000: loss 1.717107
# iteration 700 / 1000: loss 1.578780
# iteration 800 / 1000: loss 1.404942
# iteration 900 / 1000: loss 1.585021
# lr 1.000000e-03 rs 0.175000 bs 300 ni 1000 hs 50 train accuracy 0.496816 val accuracy 0.472000
# iteration 0 / 1000: loss 2.302974
# iteration 100 / 1000: loss 1.927154
# iteration 200 / 1000: loss 1.782756
# iteration 300 / 1000: loss 1.565164
# iteration 400 / 1000: loss 1.630991
# iteration 500 / 1000: loss 1.615258
# iteration 600 / 1000: loss 1.578968
# iteration 700 / 1000: loss 1.499347
# iteration 800 / 1000: loss 1.389311
# iteration 900 / 1000: loss 1.506658
# lr 1.000000e-03 rs 0.175000 bs 300 ni 1000 hs 75 train accuracy 0.505327 val accuracy 0.472000
# iteration 0 / 1000: loss 2.303160
# iteration 100 / 1000: loss 1.918858
# iteration 200 / 1000: loss 1.756810
# iteration 300 / 1000: loss 1.665702
# iteration 400 / 1000: loss 1.621115
# iteration 500 / 1000: loss 1.543992
# iteration 600 / 1000: loss 1.444479
# iteration 700 / 1000: loss 1.467836
# iteration 800 / 1000: loss 1.489553
# iteration 900 / 1000: loss 1.380990
# lr 1.000000e-03 rs 0.175000 bs 300 ni 1000 hs 100 train accuracy 0.506265 val accuracy 0.481000
# iteration 0 / 1500: loss 2.302846
# iteration 100 / 1500: loss 1.937314
# iteration 200 / 1500: loss 1.828618
# iteration 300 / 1500: loss 1.648960
# iteration 400 / 1500: loss 1.648606
# iteration 500 / 1500: loss 1.529948
# iteration 600 / 1500: loss 1.619511
# iteration 700 / 1500: loss 1.551663
# iteration 800 / 1500: loss 1.388484
# iteration 900 / 1500: loss 1.463712
# iteration 1000 / 1500: loss 1.465488
# iteration 1100 / 1500: loss 1.479191
# iteration 1200 / 1500: loss 1.518086
# iteration 1300 / 1500: loss 1.552124
# iteration 1400 / 1500: loss 1.401302
# lr 1.000000e-03 rs 0.175000 bs 300 ni 1500 hs 50 train accuracy 0.521204 val accuracy 0.495000
# iteration 0 / 1500: loss 2.302983
# iteration 100 / 1500: loss 1.949749
# iteration 200 / 1500: loss 1.797803
# iteration 300 / 1500: loss 1.676867
# iteration 400 / 1500: loss 1.644917
# iteration 500 / 1500: loss 1.531168
# iteration 600 / 1500: loss 1.569021
# iteration 700 / 1500: loss 1.503339
# iteration 800 / 1500: loss 1.501724
# iteration 900 / 1500: loss 1.639101
# iteration 1000 / 1500: loss 1.455022
# iteration 1100 / 1500: loss 1.446630
# iteration 1200 / 1500: loss 1.390246
# iteration 1300 / 1500: loss 1.505887
# iteration 1400 / 1500: loss 1.466065
# lr 1.000000e-03 rs 0.175000 bs 300 ni 1500 hs 75 train accuracy 0.521265 val accuracy 0.483000
# iteration 0 / 1500: loss 2.303127
# iteration 100 / 1500: loss 1.946861
# iteration 200 / 1500: loss 1.857108
# iteration 300 / 1500: loss 1.664824
# iteration 400 / 1500: loss 1.594732
# iteration 500 / 1500: loss 1.574345
# iteration 600 / 1500: loss 1.636387
# iteration 700 / 1500: loss 1.419156
# iteration 800 / 1500: loss 1.441852
# iteration 900 / 1500: loss 1.504432
# iteration 1000 / 1500: loss 1.441754
# iteration 1100 / 1500: loss 1.355154
# iteration 1200 / 1500: loss 1.321649
# iteration 1300 / 1500: loss 1.465598
# iteration 1400 / 1500: loss 1.328256
# lr 1.000000e-03 rs 0.175000 bs 300 ni 1500 hs 100 train accuracy 0.532449 val accuracy 0.489000
# iteration 0 / 2000: loss 2.302840
# iteration 100 / 2000: loss 1.892803
# iteration 200 / 2000: loss 1.830277
# iteration 300 / 2000: loss 1.684819
# iteration 400 / 2000: loss 1.686687
# iteration 500 / 2000: loss 1.582288
# iteration 600 / 2000: loss 1.545165
# iteration 700 / 2000: loss 1.475997
# iteration 800 / 2000: loss 1.558642
# iteration 900 / 2000: loss 1.526270
# iteration 1000 / 2000: loss 1.560945
# iteration 1100 / 2000: loss 1.459861
# iteration 1200 / 2000: loss 1.328168
# iteration 1300 / 2000: loss 1.462478
# iteration 1400 / 2000: loss 1.440366
# iteration 1500 / 2000: loss 1.291134
# iteration 1600 / 2000: loss 1.454867
# iteration 1700 / 2000: loss 1.393980
# iteration 1800 / 2000: loss 1.541395
# iteration 1900 / 2000: loss 1.486958
# lr 1.000000e-03 rs 0.175000 bs 300 ni 2000 hs 50 train accuracy 0.524286 val accuracy 0.490000
# iteration 0 / 2000: loss 2.303034
# iteration 100 / 2000: loss 1.974837
# iteration 200 / 2000: loss 1.756657
# iteration 300 / 2000: loss 1.713864
# iteration 400 / 2000: loss 1.534287
# iteration 500 / 2000: loss 1.596961
# iteration 600 / 2000: loss 1.494683
# iteration 700 / 2000: loss 1.526495
# iteration 800 / 2000: loss 1.464946
# iteration 900 / 2000: loss 1.592662
# iteration 1000 / 2000: loss 1.415468
# iteration 1100 / 2000: loss 1.400348
# iteration 1200 / 2000: loss 1.518103
# iteration 1300 / 2000: loss 1.459284
# iteration 1400 / 2000: loss 1.423471
# iteration 1500 / 2000: loss 1.377086
# iteration 1600 / 2000: loss 1.448411
# iteration 1700 / 2000: loss 1.529685
# iteration 1800 / 2000: loss 1.284736
# iteration 1900 / 2000: loss 1.355101
# lr 1.000000e-03 rs 0.175000 bs 300 ni 2000 hs 75 train accuracy 0.541878 val accuracy 0.489000
# iteration 0 / 2000: loss 2.303165
# iteration 100 / 2000: loss 1.911626
# iteration 200 / 2000: loss 1.746046
# iteration 300 / 2000: loss 1.659463
# iteration 400 / 2000: loss 1.637764
# iteration 500 / 2000: loss 1.614932
# iteration 600 / 2000: loss 1.457059
# iteration 700 / 2000: loss 1.516162
# iteration 800 / 2000: loss 1.600290
# iteration 900 / 2000: loss 1.463676
# iteration 1000 / 2000: loss 1.586587
# iteration 1100 / 2000: loss 1.487907
# iteration 1200 / 2000: loss 1.336249
# iteration 1300 / 2000: loss 1.400355
# iteration 1400 / 2000: loss 1.463327
# iteration 1500 / 2000: loss 1.449678
# iteration 1600 / 2000: loss 1.406426
# iteration 1700 / 2000: loss 1.371584
# iteration 1800 / 2000: loss 1.248122
# iteration 1900 / 2000: loss 1.310053
# lr 1.000000e-03 rs 0.175000 bs 300 ni 2000 hs 100 train accuracy 0.553469 val accuracy 0.494000
# iteration 0 / 1000: loss 2.302843
# iteration 100 / 1000: loss 1.912946
# iteration 200 / 1000: loss 1.766105
# iteration 300 / 1000: loss 1.709605
# iteration 400 / 1000: loss 1.620172
# iteration 500 / 1000: loss 1.593322
# iteration 600 / 1000: loss 1.523646
# iteration 700 / 1000: loss 1.544267
# iteration 800 / 1000: loss 1.571614
# iteration 900 / 1000: loss 1.429746
# lr 1.000000e-03 rs 0.175000 bs 400 ni 1000 hs 50 train accuracy 0.501286 val accuracy 0.496000
# iteration 0 / 1000: loss 2.303018
# iteration 100 / 1000: loss 1.943937
# iteration 200 / 1000: loss 1.783604
# iteration 300 / 1000: loss 1.772157
# iteration 400 / 1000: loss 1.614366
# iteration 500 / 1000: loss 1.528594
# iteration 600 / 1000: loss 1.596228
# iteration 700 / 1000: loss 1.614727
# iteration 800 / 1000: loss 1.440816
# iteration 900 / 1000: loss 1.498448
# lr 1.000000e-03 rs 0.175000 bs 400 ni 1000 hs 75 train accuracy 0.515204 val accuracy 0.480000
# iteration 0 / 1000: loss 2.303109
# iteration 100 / 1000: loss 1.962233
# iteration 200 / 1000: loss 1.738974
# iteration 300 / 1000: loss 1.586085
# iteration 400 / 1000: loss 1.532612
# iteration 500 / 1000: loss 1.578246
# iteration 600 / 1000: loss 1.490985
# iteration 700 / 1000: loss 1.525644
# iteration 800 / 1000: loss 1.454709
# iteration 900 / 1000: loss 1.406632
# lr 1.000000e-03 rs 0.175000 bs 400 ni 1000 hs 100 train accuracy 0.517898 val accuracy 0.483000
# iteration 0 / 1500: loss 2.302872
# iteration 100 / 1500: loss 1.941175
# iteration 200 / 1500: loss 1.700750
# iteration 300 / 1500: loss 1.662803
# iteration 400 / 1500: loss 1.659777
# iteration 500 / 1500: loss 1.540259
# iteration 600 / 1500: loss 1.522676
# iteration 700 / 1500: loss 1.627459
# iteration 800 / 1500: loss 1.488650
# iteration 900 / 1500: loss 1.436207
# iteration 1000 / 1500: loss 1.492690
# iteration 1100 / 1500: loss 1.460731
# iteration 1200 / 1500: loss 1.536638
# iteration 1300 / 1500: loss 1.423518
# iteration 1400 / 1500: loss 1.403164
# lr 1.000000e-03 rs 0.175000 bs 400 ni 1500 hs 50 train accuracy 0.526184 val accuracy 0.496000
# iteration 0 / 1500: loss 2.303007
# iteration 100 / 1500: loss 1.937966
# iteration 200 / 1500: loss 1.765317
# iteration 300 / 1500: loss 1.612307
# iteration 400 / 1500: loss 1.666480
# iteration 500 / 1500: loss 1.524946
# iteration 600 / 1500: loss 1.487593
# iteration 700 / 1500: loss 1.614207
# iteration 800 / 1500: loss 1.564133
# iteration 900 / 1500: loss 1.464696
# iteration 1000 / 1500: loss 1.385708
# iteration 1100 / 1500: loss 1.404957
# iteration 1200 / 1500: loss 1.338308
# iteration 1300 / 1500: loss 1.411768
# iteration 1400 / 1500: loss 1.410506
# lr 1.000000e-03 rs 0.175000 bs 400 ni 1500 hs 75 train accuracy 0.538612 val accuracy 0.483000
# iteration 0 / 1500: loss 2.303105
# iteration 100 / 1500: loss 1.940645
# iteration 200 / 1500: loss 1.770824
# iteration 300 / 1500: loss 1.799971
# iteration 400 / 1500: loss 1.617886
# iteration 500 / 1500: loss 1.456190
# iteration 600 / 1500: loss 1.522795
# iteration 700 / 1500: loss 1.444258
# iteration 800 / 1500: loss 1.488425
# iteration 900 / 1500: loss 1.479495
# iteration 1000 / 1500: loss 1.508377
# iteration 1100 / 1500: loss 1.364046
# iteration 1200 / 1500: loss 1.415562
# iteration 1300 / 1500: loss 1.345332
# iteration 1400 / 1500: loss 1.306670
# lr 1.000000e-03 rs 0.175000 bs 400 ni 1500 hs 100 train accuracy 0.543184 val accuracy 0.489000
# iteration 0 / 2000: loss 2.302858
# iteration 100 / 2000: loss 1.918752
# iteration 200 / 2000: loss 1.746172
# iteration 300 / 2000: loss 1.685861
# iteration 400 / 2000: loss 1.681122
# iteration 500 / 2000: loss 1.539798
# iteration 600 / 2000: loss 1.550434
# iteration 700 / 2000: loss 1.451760
# iteration 800 / 2000: loss 1.451970
# iteration 900 / 2000: loss 1.462715
# iteration 1000 / 2000: loss 1.495077
# iteration 1100 / 2000: loss 1.484811
# iteration 1200 / 2000: loss 1.441756
# iteration 1300 / 2000: loss 1.422246
# iteration 1400 / 2000: loss 1.507745
# iteration 1500 / 2000: loss 1.419753
# iteration 1600 / 2000: loss 1.373455
# iteration 1700 / 2000: loss 1.440728
# iteration 1800 / 2000: loss 1.378612
# iteration 1900 / 2000: loss 1.389198
# lr 1.000000e-03 rs 0.175000 bs 400 ni 2000 hs 50 train accuracy 0.548755 val accuracy 0.497000
# iteration 0 / 2000: loss 2.303006
# iteration 100 / 2000: loss 1.941363
# iteration 200 / 2000: loss 1.786148
# iteration 300 / 2000: loss 1.698193
# iteration 400 / 2000: loss 1.554629
# iteration 500 / 2000: loss 1.554542
# iteration 600 / 2000: loss 1.531440
# iteration 700 / 2000: loss 1.529301
# iteration 800 / 2000: loss 1.453415
# iteration 900 / 2000: loss 1.508136
# iteration 1000 / 2000: loss 1.462822
# iteration 1100 / 2000: loss 1.453214
# iteration 1200 / 2000: loss 1.355584
# iteration 1300 / 2000: loss 1.436711
# iteration 1400 / 2000: loss 1.392107
# iteration 1500 / 2000: loss 1.409299
# iteration 1600 / 2000: loss 1.308390
# iteration 1700 / 2000: loss 1.318090
# iteration 1800 / 2000: loss 1.305371
# iteration 1900 / 2000: loss 1.342950
# lr 1.000000e-03 rs 0.175000 bs 400 ni 2000 hs 75 train accuracy 0.560980 val accuracy 0.510000
# iteration 0 / 2000: loss 2.303106
# iteration 100 / 2000: loss 1.945160
# iteration 200 / 2000: loss 1.734764
# iteration 300 / 2000: loss 1.667026
# iteration 400 / 2000: loss 1.601796
# iteration 500 / 2000: loss 1.534746
# iteration 600 / 2000: loss 1.543621
# iteration 700 / 2000: loss 1.436944
# iteration 800 / 2000: loss 1.468287
# iteration 900 / 2000: loss 1.445599
# iteration 1000 / 2000: loss 1.365445
# iteration 1100 / 2000: loss 1.402101
# iteration 1200 / 2000: loss 1.395388
# iteration 1300 / 2000: loss 1.423679
# iteration 1400 / 2000: loss 1.293704
# iteration 1500 / 2000: loss 1.495272
# iteration 1600 / 2000: loss 1.302007
# iteration 1700 / 2000: loss 1.272995
# iteration 1800 / 2000: loss 1.328237
# iteration 1900 / 2000: loss 1.279415
# lr 1.000000e-03 rs 0.175000 bs 400 ni 2000 hs 100 train accuracy 0.568959 val accuracy 0.504000
# iteration 0 / 1000: loss 2.302948
# iteration 100 / 1000: loss 2.008812
# iteration 200 / 1000: loss 1.720236
# iteration 300 / 1000: loss 1.741537
# iteration 400 / 1000: loss 1.643241
# iteration 500 / 1000: loss 1.605657
# iteration 600 / 1000: loss 1.592006
# iteration 700 / 1000: loss 1.583209
# iteration 800 / 1000: loss 1.548016
# iteration 900 / 1000: loss 1.616705
# lr 1.000000e-03 rs 0.250000 bs 200 ni 1000 hs 50 train accuracy 0.480776 val accuracy 0.461000
# iteration 0 / 1000: loss 2.303147
# iteration 100 / 1000: loss 1.962419
# iteration 200 / 1000: loss 1.822328
# iteration 300 / 1000: loss 1.736336
# iteration 400 / 1000: loss 1.713647
# iteration 500 / 1000: loss 1.636943
# iteration 600 / 1000: loss 1.520738
# iteration 700 / 1000: loss 1.526062
# iteration 800 / 1000: loss 1.477900
# iteration 900 / 1000: loss 1.537041
# lr 1.000000e-03 rs 0.250000 bs 200 ni 1000 hs 75 train accuracy 0.485163 val accuracy 0.469000
# iteration 0 / 1000: loss 2.303345
# iteration 100 / 1000: loss 1.869308
# iteration 200 / 1000: loss 1.701329
# iteration 300 / 1000: loss 1.754816
# iteration 400 / 1000: loss 1.719735
# iteration 500 / 1000: loss 1.561060
# iteration 600 / 1000: loss 1.625688
# iteration 700 / 1000: loss 1.647337
# iteration 800 / 1000: loss 1.499106
# iteration 900 / 1000: loss 1.513823
# lr 1.000000e-03 rs 0.250000 bs 200 ni 1000 hs 100 train accuracy 0.499102 val accuracy 0.479000
# iteration 0 / 1500: loss 2.303011
# iteration 100 / 1500: loss 2.006655
# iteration 200 / 1500: loss 1.805712
# iteration 300 / 1500: loss 1.662810
# iteration 400 / 1500: loss 1.763631
# iteration 500 / 1500: loss 1.645962
# iteration 600 / 1500: loss 1.616999
# iteration 700 / 1500: loss 1.624201
# iteration 800 / 1500: loss 1.521851
# iteration 900 / 1500: loss 1.446771
# iteration 1000 / 1500: loss 1.582892
# iteration 1100 / 1500: loss 1.500336
# iteration 1200 / 1500: loss 1.533933
# iteration 1300 / 1500: loss 1.549256
# iteration 1400 / 1500: loss 1.637179
# lr 1.000000e-03 rs 0.250000 bs 200 ni 1500 hs 50 train accuracy 0.510612 val accuracy 0.477000
# iteration 0 / 1500: loss 2.303169
# iteration 100 / 1500: loss 1.930940
# iteration 200 / 1500: loss 1.907366
# iteration 300 / 1500: loss 1.681489
# iteration 400 / 1500: loss 1.703558
# iteration 500 / 1500: loss 1.699564
# iteration 600 / 1500: loss 1.481563
# iteration 700 / 1500: loss 1.577696
# iteration 800 / 1500: loss 1.590167
# iteration 900 / 1500: loss 1.479664
# iteration 1000 / 1500: loss 1.565387
# iteration 1100 / 1500: loss 1.557175
# iteration 1200 / 1500: loss 1.506802
# iteration 1300 / 1500: loss 1.484030
# iteration 1400 / 1500: loss 1.519829
# lr 1.000000e-03 rs 0.250000 bs 200 ni 1500 hs 75 train accuracy 0.524082 val accuracy 0.511000
# iteration 0 / 1500: loss 2.303369
# iteration 100 / 1500: loss 1.977299
# iteration 200 / 1500: loss 1.853088
# iteration 300 / 1500: loss 1.776996
# iteration 400 / 1500: loss 1.707354
# iteration 500 / 1500: loss 1.535851
# iteration 600 / 1500: loss 1.594298
# iteration 700 / 1500: loss 1.569270
# iteration 800 / 1500: loss 1.489698
# iteration 900 / 1500: loss 1.548981
# iteration 1000 / 1500: loss 1.442639
# iteration 1100 / 1500: loss 1.593016
# iteration 1200 / 1500: loss 1.580700
# iteration 1300 / 1500: loss 1.594703
# iteration 1400 / 1500: loss 1.381628
# lr 1.000000e-03 rs 0.250000 bs 200 ni 1500 hs 100 train accuracy 0.528918 val accuracy 0.501000
# iteration 0 / 2000: loss 2.302965
# iteration 100 / 2000: loss 1.901731
# iteration 200 / 2000: loss 1.654729
# iteration 300 / 2000: loss 1.616061
# iteration 400 / 2000: loss 1.740481
# iteration 500 / 2000: loss 1.682347
# iteration 600 / 2000: loss 1.641334
# iteration 700 / 2000: loss 1.560713
# iteration 800 / 2000: loss 1.626246
# iteration 900 / 2000: loss 1.474595
# iteration 1000 / 2000: loss 1.646903
# iteration 1100 / 2000: loss 1.556820
# iteration 1200 / 2000: loss 1.502097
# iteration 1300 / 2000: loss 1.358597
# iteration 1400 / 2000: loss 1.388955
# iteration 1500 / 2000: loss 1.472049
# iteration 1600 / 2000: loss 1.435171
# iteration 1700 / 2000: loss 1.391999
# iteration 1800 / 2000: loss 1.440491
# iteration 1900 / 2000: loss 1.423354
# lr 1.000000e-03 rs 0.250000 bs 200 ni 2000 hs 50 train accuracy 0.524041 val accuracy 0.497000
# iteration 0 / 2000: loss 2.303169
# iteration 100 / 2000: loss 1.966475
# iteration 200 / 2000: loss 1.744013
# iteration 300 / 2000: loss 1.630583
# iteration 400 / 2000: loss 1.532584
# iteration 500 / 2000: loss 1.636934
# iteration 600 / 2000: loss 1.591463
# iteration 700 / 2000: loss 1.592415
# iteration 800 / 2000: loss 1.657099
# iteration 900 / 2000: loss 1.547500
# iteration 1000 / 2000: loss 1.410388
# iteration 1100 / 2000: loss 1.460019
# iteration 1200 / 2000: loss 1.616236
# iteration 1300 / 2000: loss 1.514614
# iteration 1400 / 2000: loss 1.561620
# iteration 1500 / 2000: loss 1.426762
# iteration 1600 / 2000: loss 1.418544
# iteration 1700 / 2000: loss 1.525692
# iteration 1800 / 2000: loss 1.511536
# iteration 1900 / 2000: loss 1.445698
# lr 1.000000e-03 rs 0.250000 bs 200 ni 2000 hs 75 train accuracy 0.531286 val accuracy 0.513000
# iteration 0 / 2000: loss 2.303341
# iteration 100 / 2000: loss 1.874260
# iteration 200 / 2000: loss 1.870483
# iteration 300 / 2000: loss 1.737657
# iteration 400 / 2000: loss 1.667088
# iteration 500 / 2000: loss 1.600976
# iteration 600 / 2000: loss 1.596055
# iteration 700 / 2000: loss 1.453290
# iteration 800 / 2000: loss 1.500582
# iteration 900 / 2000: loss 1.477340
# iteration 1000 / 2000: loss 1.616312
# iteration 1100 / 2000: loss 1.513116
# iteration 1200 / 2000: loss 1.530019
# iteration 1300 / 2000: loss 1.594734
# iteration 1400 / 2000: loss 1.420985
# iteration 1500 / 2000: loss 1.452566
# iteration 1600 / 2000: loss 1.445844
# iteration 1700 / 2000: loss 1.387775
# iteration 1800 / 2000: loss 1.496387
# iteration 1900 / 2000: loss 1.497926
# lr 1.000000e-03 rs 0.250000 bs 200 ni 2000 hs 100 train accuracy 0.550796 val accuracy 0.500000
# iteration 0 / 1000: loss 2.302963
# iteration 100 / 1000: loss 1.952478
# iteration 200 / 1000: loss 1.754823
# iteration 300 / 1000: loss 1.655681
# iteration 400 / 1000: loss 1.604971
# iteration 500 / 1000: loss 1.539222
# iteration 600 / 1000: loss 1.541550
# iteration 700 / 1000: loss 1.602085
# iteration 800 / 1000: loss 1.570197
# iteration 900 / 1000: loss 1.504145
# lr 1.000000e-03 rs 0.250000 bs 300 ni 1000 hs 50 train accuracy 0.484306 val accuracy 0.449000
# iteration 0 / 1000: loss 2.303169
# iteration 100 / 1000: loss 1.927621
# iteration 200 / 1000: loss 1.734472
# iteration 300 / 1000: loss 1.719192
# iteration 400 / 1000: loss 1.579526
# iteration 500 / 1000: loss 1.485734
# iteration 600 / 1000: loss 1.564019
# iteration 700 / 1000: loss 1.433883
# iteration 800 / 1000: loss 1.402535
# iteration 900 / 1000: loss 1.413781
# lr 1.000000e-03 rs 0.250000 bs 300 ni 1000 hs 75 train accuracy 0.504878 val accuracy 0.476000
# iteration 0 / 1000: loss 2.303354
# iteration 100 / 1000: loss 1.959890
# iteration 200 / 1000: loss 1.746879
# iteration 300 / 1000: loss 1.709819
# iteration 400 / 1000: loss 1.604889
# iteration 500 / 1000: loss 1.591812
# iteration 600 / 1000: loss 1.555681
# iteration 700 / 1000: loss 1.480921
# iteration 800 / 1000: loss 1.513863
# iteration 900 / 1000: loss 1.515231
# lr 1.000000e-03 rs 0.250000 bs 300 ni 1000 hs 100 train accuracy 0.509061 val accuracy 0.488000
# iteration 0 / 1500: loss 2.302931
# iteration 100 / 1500: loss 1.997956
# iteration 200 / 1500: loss 1.723718
# iteration 300 / 1500: loss 1.702080
# iteration 400 / 1500: loss 1.604062
# iteration 500 / 1500: loss 1.555579
# iteration 600 / 1500: loss 1.668490
# iteration 700 / 1500: loss 1.383364
# iteration 800 / 1500: loss 1.542008
# iteration 900 / 1500: loss 1.517320
# iteration 1000 / 1500: loss 1.433643
# iteration 1100 / 1500: loss 1.412796
# iteration 1200 / 1500: loss 1.487883
# iteration 1300 / 1500: loss 1.557232
# iteration 1400 / 1500: loss 1.539656
# lr 1.000000e-03 rs 0.250000 bs 300 ni 1500 hs 50 train accuracy 0.519980 val accuracy 0.491000
# iteration 0 / 1500: loss 2.303198
# iteration 100 / 1500: loss 1.901130
# iteration 200 / 1500: loss 1.674156
# iteration 300 / 1500: loss 1.747363
# iteration 400 / 1500: loss 1.648679
# iteration 500 / 1500: loss 1.560730
# iteration 600 / 1500: loss 1.519145
# iteration 700 / 1500: loss 1.544371
# iteration 800 / 1500: loss 1.503580
# iteration 900 / 1500: loss 1.553439
# iteration 1000 / 1500: loss 1.502193
# iteration 1100 / 1500: loss 1.423830
# iteration 1200 / 1500: loss 1.520579
# iteration 1300 / 1500: loss 1.457985
# iteration 1400 / 1500: loss 1.438458
# lr 1.000000e-03 rs 0.250000 bs 300 ni 1500 hs 75 train accuracy 0.518796 val accuracy 0.510000
# iteration 0 / 1500: loss 2.303364
# iteration 100 / 1500: loss 1.976501
# iteration 200 / 1500: loss 1.807841
# iteration 300 / 1500: loss 1.627448
# iteration 400 / 1500: loss 1.597944
# iteration 500 / 1500: loss 1.636365
# iteration 600 / 1500: loss 1.474530
# iteration 700 / 1500: loss 1.557536
# iteration 800 / 1500: loss 1.514460
# iteration 900 / 1500: loss 1.553782
# iteration 1000 / 1500: loss 1.537425
# iteration 1100 / 1500: loss 1.518058
# iteration 1200 / 1500: loss 1.503936
# iteration 1300 / 1500: loss 1.372609
# iteration 1400 / 1500: loss 1.418195
# lr 1.000000e-03 rs 0.250000 bs 300 ni 1500 hs 100 train accuracy 0.537714 val accuracy 0.488000
# iteration 0 / 2000: loss 2.302972
# iteration 100 / 2000: loss 1.960778
# iteration 200 / 2000: loss 1.815288
# iteration 300 / 2000: loss 1.623350
# iteration 400 / 2000: loss 1.616416
# iteration 500 / 2000: loss 1.536151
# iteration 600 / 2000: loss 1.548254
# iteration 700 / 2000: loss 1.659949
# iteration 800 / 2000: loss 1.474134
# iteration 900 / 2000: loss 1.507641
# iteration 1000 / 2000: loss 1.514691
# iteration 1100 / 2000: loss 1.477227
# iteration 1200 / 2000: loss 1.454988
# iteration 1300 / 2000: loss 1.459738
# iteration 1400 / 2000: loss 1.416491
# iteration 1500 / 2000: loss 1.452097
# iteration 1600 / 2000: loss 1.506299
# iteration 1700 / 2000: loss 1.432688
# iteration 1800 / 2000: loss 1.488889
# iteration 1900 / 2000: loss 1.579513
# lr 1.000000e-03 rs 0.250000 bs 300 ni 2000 hs 50 train accuracy 0.531735 val accuracy 0.509000
# iteration 0 / 2000: loss 2.303150
# iteration 100 / 2000: loss 1.954693
# iteration 200 / 2000: loss 1.830802
# iteration 300 / 2000: loss 1.681803
# iteration 400 / 2000: loss 1.724023
# iteration 500 / 2000: loss 1.532204
# iteration 600 / 2000: loss 1.610173
# iteration 700 / 2000: loss 1.524517
# iteration 800 / 2000: loss 1.642023
# iteration 900 / 2000: loss 1.473089
# iteration 1000 / 2000: loss 1.558439
# iteration 1100 / 2000: loss 1.537014
# iteration 1200 / 2000: loss 1.443993
# iteration 1300 / 2000: loss 1.424962
# iteration 1400 / 2000: loss 1.431945
# iteration 1500 / 2000: loss 1.489083
# iteration 1600 / 2000: loss 1.470750
# iteration 1700 / 2000: loss 1.435954
# iteration 1800 / 2000: loss 1.658591
# iteration 1900 / 2000: loss 1.354892
# lr 1.000000e-03 rs 0.250000 bs 300 ni 2000 hs 75 train accuracy 0.531959 val accuracy 0.481000
# iteration 0 / 2000: loss 2.303355
# iteration 100 / 2000: loss 1.963551
# iteration 200 / 2000: loss 1.842957
# iteration 300 / 2000: loss 1.737275
# iteration 400 / 2000: loss 1.546185
# iteration 500 / 2000: loss 1.463531
# iteration 600 / 2000: loss 1.649747
# iteration 700 / 2000: loss 1.431991
# iteration 800 / 2000: loss 1.509017
# iteration 900 / 2000: loss 1.609316
# iteration 1000 / 2000: loss 1.532462
# iteration 1100 / 2000: loss 1.453790
# iteration 1200 / 2000: loss 1.549966
# iteration 1300 / 2000: loss 1.424913
# iteration 1400 / 2000: loss 1.382079
# iteration 1500 / 2000: loss 1.458325
# iteration 1600 / 2000: loss 1.301462
# iteration 1700 / 2000: loss 1.247963
# iteration 1800 / 2000: loss 1.404846
# iteration 1900 / 2000: loss 1.404824
# lr 1.000000e-03 rs 0.250000 bs 300 ni 2000 hs 100 train accuracy 0.536000 val accuracy 0.502000
# iteration 0 / 1000: loss 2.302972
# iteration 100 / 1000: loss 1.991407
# iteration 200 / 1000: loss 1.756497
# iteration 300 / 1000: loss 1.735773
# iteration 400 / 1000: loss 1.621300
# iteration 500 / 1000: loss 1.572767
# iteration 600 / 1000: loss 1.582994
# iteration 700 / 1000: loss 1.525099
# iteration 800 / 1000: loss 1.513797
# iteration 900 / 1000: loss 1.586324
# lr 1.000000e-03 rs 0.250000 bs 400 ni 1000 hs 50 train accuracy 0.495551 val accuracy 0.493000
# iteration 0 / 1000: loss 2.303141
# iteration 100 / 1000: loss 1.950839
# iteration 200 / 1000: loss 1.758331
# iteration 300 / 1000: loss 1.692788
# iteration 400 / 1000: loss 1.627280
# iteration 500 / 1000: loss 1.594890
# iteration 600 / 1000: loss 1.619642
# iteration 700 / 1000: loss 1.519339
# iteration 800 / 1000: loss 1.456247
# iteration 900 / 1000: loss 1.493254
# lr 1.000000e-03 rs 0.250000 bs 400 ni 1000 hs 75 train accuracy 0.502878 val accuracy 0.479000
# iteration 0 / 1000: loss 2.303349
# iteration 100 / 1000: loss 1.941111
# iteration 200 / 1000: loss 1.824478
# iteration 300 / 1000: loss 1.698497
# iteration 400 / 1000: loss 1.643582
# iteration 500 / 1000: loss 1.543661
# iteration 600 / 1000: loss 1.626136
# iteration 700 / 1000: loss 1.497855
# iteration 800 / 1000: loss 1.469321
# iteration 900 / 1000: loss 1.387828
# lr 1.000000e-03 rs 0.250000 bs 400 ni 1000 hs 100 train accuracy 0.509122 val accuracy 0.483000
# iteration 0 / 1500: loss 2.302958
# iteration 100 / 1500: loss 1.932601
# iteration 200 / 1500: loss 1.834523
# iteration 300 / 1500: loss 1.632567
# iteration 400 / 1500: loss 1.642099
# iteration 500 / 1500: loss 1.578024
# iteration 600 / 1500: loss 1.578228
# iteration 700 / 1500: loss 1.620828
# iteration 800 / 1500: loss 1.438483
# iteration 900 / 1500: loss 1.466612
# iteration 1000 / 1500: loss 1.554317
# iteration 1100 / 1500: loss 1.404564
# iteration 1200 / 1500: loss 1.522702
# iteration 1300 / 1500: loss 1.520177
# iteration 1400 / 1500: loss 1.455747
# lr 1.000000e-03 rs 0.250000 bs 400 ni 1500 hs 50 train accuracy 0.521980 val accuracy 0.492000
# iteration 0 / 1500: loss 2.303159
# iteration 100 / 1500: loss 1.897817
# iteration 200 / 1500: loss 1.755323
# iteration 300 / 1500: loss 1.710285
# iteration 400 / 1500: loss 1.732855
# iteration 500 / 1500: loss 1.586899
# iteration 600 / 1500: loss 1.630450
# iteration 700 / 1500: loss 1.471666
# iteration 800 / 1500: loss 1.529620
# iteration 900 / 1500: loss 1.471892
# iteration 1000 / 1500: loss 1.456256
# iteration 1100 / 1500: loss 1.373113
# iteration 1200 / 1500: loss 1.436712
# iteration 1300 / 1500: loss 1.341882
# iteration 1400 / 1500: loss 1.463257
# lr 1.000000e-03 rs 0.250000 bs 400 ni 1500 hs 75 train accuracy 0.529755 val accuracy 0.498000
# iteration 0 / 1500: loss 2.303352
# iteration 100 / 1500: loss 1.925067
# iteration 200 / 1500: loss 1.734958
# iteration 300 / 1500: loss 1.639041
# iteration 400 / 1500: loss 1.604663
# iteration 500 / 1500: loss 1.549085
# iteration 600 / 1500: loss 1.609053
# iteration 700 / 1500: loss 1.448665
# iteration 800 / 1500: loss 1.572982
# iteration 900 / 1500: loss 1.425671
# iteration 1000 / 1500: loss 1.478830
# iteration 1100 / 1500: loss 1.470025
# iteration 1200 / 1500: loss 1.419498
# iteration 1300 / 1500: loss 1.468273
# iteration 1400 / 1500: loss 1.387125
# lr 1.000000e-03 rs 0.250000 bs 400 ni 1500 hs 100 train accuracy 0.539816 val accuracy 0.490000
# iteration 0 / 2000: loss 2.303006
# iteration 100 / 2000: loss 1.961689
# iteration 200 / 2000: loss 1.755787
# iteration 300 / 2000: loss 1.704410
# iteration 400 / 2000: loss 1.707877
# iteration 500 / 2000: loss 1.654137
# iteration 600 / 2000: loss 1.576344
# iteration 700 / 2000: loss 1.560626
# iteration 800 / 2000: loss 1.459043
# iteration 900 / 2000: loss 1.452179
# iteration 1000 / 2000: loss 1.493870
# iteration 1100 / 2000: loss 1.478293
# iteration 1200 / 2000: loss 1.537444
# iteration 1300 / 2000: loss 1.368505
# iteration 1400 / 2000: loss 1.478841
# iteration 1500 / 2000: loss 1.412575
# iteration 1600 / 2000: loss 1.480617
# iteration 1700 / 2000: loss 1.357698
# iteration 1800 / 2000: loss 1.388159
# iteration 1900 / 2000: loss 1.391366
# lr 1.000000e-03 rs 0.250000 bs 400 ni 2000 hs 50 train accuracy 0.534571 val accuracy 0.497000
# iteration 0 / 2000: loss 2.303169
# iteration 100 / 2000: loss 1.946676
# iteration 200 / 2000: loss 1.720432
# iteration 300 / 2000: loss 1.664491
# iteration 400 / 2000: loss 1.626837
# iteration 500 / 2000: loss 1.484718
# iteration 600 / 2000: loss 1.625279
# iteration 700 / 2000: loss 1.559798
# iteration 800 / 2000: loss 1.481469
# iteration 900 / 2000: loss 1.514724
# iteration 1000 / 2000: loss 1.469184
# iteration 1100 / 2000: loss 1.427507
# iteration 1200 / 2000: loss 1.466213
# iteration 1300 / 2000: loss 1.408292
# iteration 1400 / 2000: loss 1.445986
# iteration 1500 / 2000: loss 1.451988
# iteration 1600 / 2000: loss 1.412522
# iteration 1700 / 2000: loss 1.478590
# iteration 1800 / 2000: loss 1.378217
# iteration 1900 / 2000: loss 1.401513
# lr 1.000000e-03 rs 0.250000 bs 400 ni 2000 hs 75 train accuracy 0.553408 val accuracy 0.511000
# iteration 0 / 2000: loss 2.303376
# iteration 100 / 2000: loss 2.019845
# iteration 200 / 2000: loss 1.763562
# iteration 300 / 2000: loss 1.705067
# iteration 400 / 2000: loss 1.598988
# iteration 500 / 2000: loss 1.655758
# iteration 600 / 2000: loss 1.457177
# iteration 700 / 2000: loss 1.521426
# iteration 800 / 2000: loss 1.509409
# iteration 900 / 2000: loss 1.464582
# iteration 1000 / 2000: loss 1.451947
# iteration 1100 / 2000: loss 1.422033
# iteration 1200 / 2000: loss 1.367145
# iteration 1300 / 2000: loss 1.442061
# iteration 1400 / 2000: loss 1.402038
# iteration 1500 / 2000: loss 1.444484
# iteration 1600 / 2000: loss 1.397692
# iteration 1700 / 2000: loss 1.381573
# iteration 1800 / 2000: loss 1.386124
# iteration 1900 / 2000: loss 1.507778
# lr 1.000000e-03 rs 0.250000 bs 400 ni 2000 hs 100 train accuracy 0.567143 val accuracy 0.525000
# iteration 0 / 1000: loss 2.303381
# iteration 100 / 1000: loss 1.899387
# iteration 200 / 1000: loss 1.866889
# iteration 300 / 1000: loss 1.968200
# iteration 400 / 1000: loss 1.614125
# iteration 500 / 1000: loss 1.598768
# iteration 600 / 1000: loss 1.618793
# iteration 700 / 1000: loss 1.686111
# iteration 800 / 1000: loss 1.573432
# iteration 900 / 1000: loss 1.653534
# lr 1.000000e-03 rs 0.500000 bs 200 ni 1000 hs 50 train accuracy 0.480388 val accuracy 0.472000
# iteration 0 / 1000: loss 2.303740
# iteration 100 / 1000: loss 1.926746
# iteration 200 / 1000: loss 1.829340
# iteration 300 / 1000: loss 1.728374
# iteration 400 / 1000: loss 1.563224
# iteration 500 / 1000: loss 1.538464
# iteration 600 / 1000: loss 1.528870
# iteration 700 / 1000: loss 1.633513
# iteration 800 / 1000: loss 1.503490
# iteration 900 / 1000: loss 1.548509
# lr 1.000000e-03 rs 0.500000 bs 200 ni 1000 hs 75 train accuracy 0.490184 val accuracy 0.488000
# iteration 0 / 1000: loss 2.304110
# iteration 100 / 1000: loss 1.891153
# iteration 200 / 1000: loss 1.847948
# iteration 300 / 1000: loss 1.646297
# iteration 400 / 1000: loss 1.623376
# iteration 500 / 1000: loss 1.640593
# iteration 600 / 1000: loss 1.609946
# iteration 700 / 1000: loss 1.646203
# iteration 800 / 1000: loss 1.430456
# iteration 900 / 1000: loss 1.604321
# lr 1.000000e-03 rs 0.500000 bs 200 ni 1000 hs 100 train accuracy 0.495082 val accuracy 0.470000
# iteration 0 / 1500: loss 2.303353
# iteration 100 / 1500: loss 1.954413
# iteration 200 / 1500: loss 1.795618
# iteration 300 / 1500: loss 1.699599
# iteration 400 / 1500: loss 1.689033
# iteration 500 / 1500: loss 1.524437
# iteration 600 / 1500: loss 1.707711
# iteration 700 / 1500: loss 1.654120
# iteration 800 / 1500: loss 1.534970
# iteration 900 / 1500: loss 1.524217
# iteration 1000 / 1500: loss 1.546169
# iteration 1100 / 1500: loss 1.571453
# iteration 1200 / 1500: loss 1.513917
# iteration 1300 / 1500: loss 1.522942
# iteration 1400 / 1500: loss 1.611547
# lr 1.000000e-03 rs 0.500000 bs 200 ni 1500 hs 50 train accuracy 0.497837 val accuracy 0.482000
# iteration 0 / 1500: loss 2.303753
# iteration 100 / 1500: loss 2.026287
# iteration 200 / 1500: loss 1.796312
# iteration 300 / 1500: loss 1.783791
# iteration 400 / 1500: loss 1.591376
# iteration 500 / 1500: loss 1.675432
# iteration 600 / 1500: loss 1.576745
# iteration 700 / 1500: loss 1.582172
# iteration 800 / 1500: loss 1.623555
# iteration 900 / 1500: loss 1.598147
# iteration 1000 / 1500: loss 1.535809
# iteration 1100 / 1500: loss 1.570416
# iteration 1200 / 1500: loss 1.600653
# iteration 1300 / 1500: loss 1.542764
# iteration 1400 / 1500: loss 1.554613
# lr 1.000000e-03 rs 0.500000 bs 200 ni 1500 hs 75 train accuracy 0.513265 val accuracy 0.474000
# iteration 0 / 1500: loss 2.304115
# iteration 100 / 1500: loss 2.087921
# iteration 200 / 1500: loss 1.802696
# iteration 300 / 1500: loss 1.781872
# iteration 400 / 1500: loss 1.659242
# iteration 500 / 1500: loss 1.600195
# iteration 600 / 1500: loss 1.620363
# iteration 700 / 1500: loss 1.632122
# iteration 800 / 1500: loss 1.565710
# iteration 900 / 1500: loss 1.647307
# iteration 1000 / 1500: loss 1.531968
# iteration 1100 / 1500: loss 1.477275
# iteration 1200 / 1500: loss 1.633045
# iteration 1300 / 1500: loss 1.634094
# iteration 1400 / 1500: loss 1.514917
# lr 1.000000e-03 rs 0.500000 bs 200 ni 1500 hs 100 train accuracy 0.519020 val accuracy 0.505000
# iteration 0 / 2000: loss 2.303322
# iteration 100 / 2000: loss 1.927712
# iteration 200 / 2000: loss 1.791348
# iteration 300 / 2000: loss 1.746500
# iteration 400 / 2000: loss 1.721820
# iteration 500 / 2000: loss 1.669342
# iteration 600 / 2000: loss 1.704744
# iteration 700 / 2000: loss 1.659452
# iteration 800 / 2000: loss 1.662560
# iteration 900 / 2000: loss 1.698675
# iteration 1000 / 2000: loss 1.632731
# iteration 1100 / 2000: loss 1.470461
# iteration 1200 / 2000: loss 1.503703
# iteration 1300 / 2000: loss 1.620533
# iteration 1400 / 2000: loss 1.537186
# iteration 1500 / 2000: loss 1.569919
# iteration 1600 / 2000: loss 1.461395
# iteration 1700 / 2000: loss 1.551354
# iteration 1800 / 2000: loss 1.536965
# iteration 1900 / 2000: loss 1.603531
# lr 1.000000e-03 rs 0.500000 bs 200 ni 2000 hs 50 train accuracy 0.506265 val accuracy 0.479000
# iteration 0 / 2000: loss 2.303763
# iteration 100 / 2000: loss 2.010074
# iteration 200 / 2000: loss 1.732698
# iteration 300 / 2000: loss 1.702889
# iteration 400 / 2000: loss 1.644188
# iteration 500 / 2000: loss 1.662636
# iteration 600 / 2000: loss 1.773455
# iteration 700 / 2000: loss 1.609116
# iteration 800 / 2000: loss 1.554017
# iteration 900 / 2000: loss 1.490603
# iteration 1000 / 2000: loss 1.594696
# iteration 1100 / 2000: loss 1.547732
# iteration 1200 / 2000: loss 1.461892
# iteration 1300 / 2000: loss 1.675740
# iteration 1400 / 2000: loss 1.474993
# iteration 1500 / 2000: loss 1.578946
# iteration 1600 / 2000: loss 1.548224
# iteration 1700 / 2000: loss 1.518235
# iteration 1800 / 2000: loss 1.530749
# iteration 1900 / 2000: loss 1.531613
# lr 1.000000e-03 rs 0.500000 bs 200 ni 2000 hs 75 train accuracy 0.519592 val accuracy 0.489000
# iteration 0 / 2000: loss 2.304158
# iteration 100 / 2000: loss 1.931322
# iteration 200 / 2000: loss 1.842343
# iteration 300 / 2000: loss 1.610045
# iteration 400 / 2000: loss 1.647835
# iteration 500 / 2000: loss 1.609573
# iteration 600 / 2000: loss 1.525588
# iteration 700 / 2000: loss 1.559303
# iteration 800 / 2000: loss 1.463713
# iteration 900 / 2000: loss 1.661147
# iteration 1000 / 2000: loss 1.460076
# iteration 1100 / 2000: loss 1.582728
# iteration 1200 / 2000: loss 1.443096
# iteration 1300 / 2000: loss 1.587076
# iteration 1400 / 2000: loss 1.559697
# iteration 1500 / 2000: loss 1.590220
# iteration 1600 / 2000: loss 1.492186
# iteration 1700 / 2000: loss 1.449724
# iteration 1800 / 2000: loss 1.433225
# iteration 1900 / 2000: loss 1.552951
# lr 1.000000e-03 rs 0.500000 bs 200 ni 2000 hs 100 train accuracy 0.523571 val accuracy 0.486000
# iteration 0 / 1000: loss 2.303358
# iteration 100 / 1000: loss 1.978169
# iteration 200 / 1000: loss 1.842744
# iteration 300 / 1000: loss 1.750505
# iteration 400 / 1000: loss 1.694417
# iteration 500 / 1000: loss 1.663827
# iteration 600 / 1000: loss 1.587021
# iteration 700 / 1000: loss 1.539275
# iteration 800 / 1000: loss 1.625794
# iteration 900 / 1000: loss 1.536928
# lr 1.000000e-03 rs 0.500000 bs 300 ni 1000 hs 50 train accuracy 0.487122 val accuracy 0.474000
# iteration 0 / 1000: loss 2.303739
# iteration 100 / 1000: loss 1.894580
# iteration 200 / 1000: loss 1.795824
# iteration 300 / 1000: loss 1.786918
# iteration 400 / 1000: loss 1.637039
# iteration 500 / 1000: loss 1.620767
# iteration 600 / 1000: loss 1.535831
# iteration 700 / 1000: loss 1.454308
# iteration 800 / 1000: loss 1.546525
# iteration 900 / 1000: loss 1.515106
# lr 1.000000e-03 rs 0.500000 bs 300 ni 1000 hs 75 train accuracy 0.496918 val accuracy 0.472000
# iteration 0 / 1000: loss 2.304098
# iteration 100 / 1000: loss 1.928565
# iteration 200 / 1000: loss 1.796277
# iteration 300 / 1000: loss 1.711647
# iteration 400 / 1000: loss 1.675872
# iteration 500 / 1000: loss 1.502378
# iteration 600 / 1000: loss 1.657534
# iteration 700 / 1000: loss 1.501862
# iteration 800 / 1000: loss 1.585376
# iteration 900 / 1000: loss 1.615686
# lr 1.000000e-03 rs 0.500000 bs 300 ni 1000 hs 100 train accuracy 0.494204 val accuracy 0.472000
# iteration 0 / 1500: loss 2.303324
# iteration 100 / 1500: loss 1.986669
# iteration 200 / 1500: loss 1.770204
# iteration 300 / 1500: loss 1.670147
# iteration 400 / 1500: loss 1.601711
# iteration 500 / 1500: loss 1.682710
# iteration 600 / 1500: loss 1.610769
# iteration 700 / 1500: loss 1.549802
# iteration 800 / 1500: loss 1.597512
# iteration 900 / 1500: loss 1.511959
# iteration 1000 / 1500: loss 1.582073
# iteration 1100 / 1500: loss 1.491343
# iteration 1200 / 1500: loss 1.499334
# iteration 1300 / 1500: loss 1.622685
# iteration 1400 / 1500: loss 1.481332
# lr 1.000000e-03 rs 0.500000 bs 300 ni 1500 hs 50 train accuracy 0.508694 val accuracy 0.478000
# iteration 0 / 1500: loss 2.303723
# iteration 100 / 1500: loss 1.943511
# iteration 200 / 1500: loss 1.840431
# iteration 300 / 1500: loss 1.637927
# iteration 400 / 1500: loss 1.585849
# iteration 500 / 1500: loss 1.532417
# iteration 600 / 1500: loss 1.676810
# iteration 700 / 1500: loss 1.558541
# iteration 800 / 1500: loss 1.573464
# iteration 900 / 1500: loss 1.521920
# iteration 1000 / 1500: loss 1.531676
# iteration 1100 / 1500: loss 1.500040
# iteration 1200 / 1500: loss 1.500690
# iteration 1300 / 1500: loss 1.536739
# iteration 1400 / 1500: loss 1.464613
# lr 1.000000e-03 rs 0.500000 bs 300 ni 1500 hs 75 train accuracy 0.523184 val accuracy 0.504000
# iteration 0 / 1500: loss 2.304122
# iteration 100 / 1500: loss 1.965088
# iteration 200 / 1500: loss 1.792313
# iteration 300 / 1500: loss 1.704463
# iteration 400 / 1500: loss 1.675507
# iteration 500 / 1500: loss 1.623567
# iteration 600 / 1500: loss 1.650477
# iteration 700 / 1500: loss 1.488309
# iteration 800 / 1500: loss 1.557194
# iteration 900 / 1500: loss 1.528663
# iteration 1000 / 1500: loss 1.498717
# iteration 1100 / 1500: loss 1.544344
# iteration 1200 / 1500: loss 1.450387
# iteration 1300 / 1500: loss 1.445556
# iteration 1400 / 1500: loss 1.538206
# lr 1.000000e-03 rs 0.500000 bs 300 ni 1500 hs 100 train accuracy 0.512796 val accuracy 0.481000
# iteration 0 / 2000: loss 2.303368
# iteration 100 / 2000: loss 1.939339
# iteration 200 / 2000: loss 1.782252
# iteration 300 / 2000: loss 1.725887
# iteration 400 / 2000: loss 1.574901
# iteration 500 / 2000: loss 1.572520
# iteration 600 / 2000: loss 1.699988
# iteration 700 / 2000: loss 1.654146
# iteration 800 / 2000: loss 1.644627
# iteration 900 / 2000: loss 1.619066
# iteration 1000 / 2000: loss 1.634668
# iteration 1100 / 2000: loss 1.555997
# iteration 1200 / 2000: loss 1.702621
# iteration 1300 / 2000: loss 1.618257
# iteration 1400 / 2000: loss 1.621365
# iteration 1500 / 2000: loss 1.494642
# iteration 1600 / 2000: loss 1.474038
# iteration 1700 / 2000: loss 1.550658
# iteration 1800 / 2000: loss 1.547323
# iteration 1900 / 2000: loss 1.473844
# lr 1.000000e-03 rs 0.500000 bs 300 ni 2000 hs 50 train accuracy 0.514551 val accuracy 0.496000
# iteration 0 / 2000: loss 2.303739
# iteration 100 / 2000: loss 1.908532
# iteration 200 / 2000: loss 1.880017
# iteration 300 / 2000: loss 1.726139
# iteration 400 / 2000: loss 1.680387
# iteration 500 / 2000: loss 1.484764
# iteration 600 / 2000: loss 1.519846
# iteration 700 / 2000: loss 1.590333
# iteration 800 / 2000: loss 1.576091
# iteration 900 / 2000: loss 1.528704
# iteration 1000 / 2000: loss 1.488798
# iteration 1100 / 2000: loss 1.469455
# iteration 1200 / 2000: loss 1.512792
# iteration 1300 / 2000: loss 1.471809
# iteration 1400 / 2000: loss 1.538145
# iteration 1500 / 2000: loss 1.463161
# iteration 1600 / 2000: loss 1.513881
# iteration 1700 / 2000: loss 1.594618
# iteration 1800 / 2000: loss 1.576527
# iteration 1900 / 2000: loss 1.348664
# lr 1.000000e-03 rs 0.500000 bs 300 ni 2000 hs 75 train accuracy 0.532469 val accuracy 0.495000
# iteration 0 / 2000: loss 2.304150
# iteration 100 / 2000: loss 1.974100
# iteration 200 / 2000: loss 1.744968
# iteration 300 / 2000: loss 1.658900
# iteration 400 / 2000: loss 1.555817
# iteration 500 / 2000: loss 1.675734
# iteration 600 / 2000: loss 1.636153
# iteration 700 / 2000: loss 1.567500
# iteration 800 / 2000: loss 1.602073
# iteration 900 / 2000: loss 1.603223
# iteration 1000 / 2000: loss 1.440295
# iteration 1100 / 2000: loss 1.544502
# iteration 1200 / 2000: loss 1.545300
# iteration 1300 / 2000: loss 1.492837
# iteration 1400 / 2000: loss 1.531263
# iteration 1500 / 2000: loss 1.490642
# iteration 1600 / 2000: loss 1.494769
# iteration 1700 / 2000: loss 1.557643
# iteration 1800 / 2000: loss 1.526833
# iteration 1900 / 2000: loss 1.518550
# lr 1.000000e-03 rs 0.500000 bs 300 ni 2000 hs 100 train accuracy 0.541959 val accuracy 0.501000
# iteration 0 / 1000: loss 2.303334
# iteration 100 / 1000: loss 1.946507
# iteration 200 / 1000: loss 1.772433
# iteration 300 / 1000: loss 1.739055
# iteration 400 / 1000: loss 1.604320
# iteration 500 / 1000: loss 1.661661
# iteration 600 / 1000: loss 1.666311
# iteration 700 / 1000: loss 1.585369
# iteration 800 / 1000: loss 1.513526
# iteration 900 / 1000: loss 1.548612
# lr 1.000000e-03 rs 0.500000 bs 400 ni 1000 hs 50 train accuracy 0.488347 val accuracy 0.465000
# iteration 0 / 1000: loss 2.303748
# iteration 100 / 1000: loss 1.925428
# iteration 200 / 1000: loss 1.812730
# iteration 300 / 1000: loss 1.828768
# iteration 400 / 1000: loss 1.665521
# iteration 500 / 1000: loss 1.609211
# iteration 600 / 1000: loss 1.548236
# iteration 700 / 1000: loss 1.600610
# iteration 800 / 1000: loss 1.540057
# iteration 900 / 1000: loss 1.575046
# lr 1.000000e-03 rs 0.500000 bs 400 ni 1000 hs 75 train accuracy 0.492837 val accuracy 0.481000
# iteration 0 / 1000: loss 2.304127
# iteration 100 / 1000: loss 1.922626
# iteration 200 / 1000: loss 1.824558
# iteration 300 / 1000: loss 1.719416
# iteration 400 / 1000: loss 1.580277
# iteration 500 / 1000: loss 1.599401
# iteration 600 / 1000: loss 1.536788
# iteration 700 / 1000: loss 1.563807
# iteration 800 / 1000: loss 1.547940
# iteration 900 / 1000: loss 1.488666
# lr 1.000000e-03 rs 0.500000 bs 400 ni 1000 hs 100 train accuracy 0.499816 val accuracy 0.475000
# iteration 0 / 1500: loss 2.303358
# iteration 100 / 1500: loss 1.960272
# iteration 200 / 1500: loss 1.823794
# iteration 300 / 1500: loss 1.620354
# iteration 400 / 1500: loss 1.653673
# iteration 500 / 1500: loss 1.744118
# iteration 600 / 1500: loss 1.578587
# iteration 700 / 1500: loss 1.547562
# iteration 800 / 1500: loss 1.581062
# iteration 900 / 1500: loss 1.490237
# iteration 1000 / 1500: loss 1.581844
# iteration 1100 / 1500: loss 1.533987
# iteration 1200 / 1500: loss 1.575410
# iteration 1300 / 1500: loss 1.510636
# iteration 1400 / 1500: loss 1.503749
# lr 1.000000e-03 rs 0.500000 bs 400 ni 1500 hs 50 train accuracy 0.512327 val accuracy 0.477000
# iteration 0 / 1500: loss 2.303724
# ...
# iteration 1900 / 2000: loss 1.563074
# lr 1.500000e-03 rs 0.500000 bs 400 ni 2000 hs 100 train accuracy 0.543796 val accuracy 0.504000
# lr 1.000000e-03 rs 0.175000 bs 200 ni 1000 hs 50 train accuracy: 0.492347 val accuracy: 0.461000
# lr 1.000000e-03 rs 0.175000 bs 200 ni 1000 hs 75 train accuracy: 0.491265 val accuracy: 0.471000
# lr 1.000000e-03 rs 0.175000 bs 200 ni 1000 hs 100 train accuracy: 0.499286 val accuracy: 0.472000
# lr 1.000000e-03 rs 0.175000 bs 200 ni 1500 hs 50 train accuracy: 0.513694 val accuracy: 0.474000
# lr 1.000000e-03 rs 0.175000 bs 200 ni 1500 hs 75 train accuracy: 0.520531 val accuracy: 0.487000
# lr 1.000000e-03 rs 0.175000 bs 200 ni 1500 hs 100 train accuracy: 0.532020 val accuracy: 0.493000
# lr 1.000000e-03 rs 0.175000 bs 200 ni 2000 hs 50 train accuracy: 0.530878 val accuracy: 0.498000
# lr 1.000000e-03 rs 0.175000 bs 200 ni 2000 hs 75 train accuracy: 0.545633 val accuracy: 0.504000
# lr 1.000000e-03 rs 0.175000 bs 200 ni 2000 hs 100 train accuracy: 0.552837 val accuracy: 0.506000
# lr 1.000000e-03 rs 0.175000 bs 300 ni 1000 hs 50 train accuracy: 0.496816 val accuracy: 0.472000
# lr 1.000000e-03 rs 0.175000 bs 300 ni 1000 hs 75 train accuracy: 0.505327 val accuracy: 0.472000
# lr 1.000000e-03 rs 0.175000 bs 300 ni 1000 hs 100 train accuracy: 0.506265 val accuracy: 0.481000
# lr 1.000000e-03 rs 0.175000 bs 300 ni 1500 hs 50 train accuracy: 0.521204 val accuracy: 0.495000
# lr 1.000000e-03 rs 0.175000 bs 300 ni 1500 hs 75 train accuracy: 0.521265 val accuracy: 0.483000
# lr 1.000000e-03 rs 0.175000 bs 300 ni 1500 hs 100 train accuracy: 0.532449 val accuracy: 0.489000
# lr 1.000000e-03 rs 0.175000 bs 300 ni 2000 hs 50 train accuracy: 0.524286 val accuracy: 0.490000
# lr 1.000000e-03 rs 0.175000 bs 300 ni 2000 hs 75 train accuracy: 0.541878 val accuracy: 0.489000
# lr 1.000000e-03 rs 0.175000 bs 300 ni 2000 hs 100 train accuracy: 0.553469 val accuracy: 0.494000
# lr 1.000000e-03 rs 0.175000 bs 400 ni 1000 hs 50 train accuracy: 0.501286 val accuracy: 0.496000
# lr 1.000000e-03 rs 0.175000 bs 400 ni 1000 hs 75 train accuracy: 0.515204 val accuracy: 0.480000
# lr 1.000000e-03 rs 0.175000 bs 400 ni 1000 hs 100 train accuracy: 0.517898 val accuracy: 0.483000
# lr 1.000000e-03 rs 0.175000 bs 400 ni 1500 hs 50 train accuracy: 0.526184 val accuracy: 0.496000
# lr 1.000000e-03 rs 0.175000 bs 400 ni 1500 hs 75 train accuracy: 0.538612 val accuracy: 0.483000
# lr 1.000000e-03 rs 0.175000 bs 400 ni 1500 hs 100 train accuracy: 0.543184 val accuracy: 0.489000
# lr 1.000000e-03 rs 0.175000 bs 400 ni 2000 hs 50 train accuracy: 0.548755 val accuracy: 0.497000
# lr 1.000000e-03 rs 0.175000 bs 400 ni 2000 hs 75 train accuracy: 0.560980 val accuracy: 0.510000
# lr 1.000000e-03 rs 0.175000 bs 400 ni 2000 hs 100 train accuracy: 0.568959 val accuracy: 0.504000
# lr 1.000000e-03 rs 0.250000 bs 200 ni 1000 hs 50 train accuracy: 0.480776 val accuracy: 0.461000
# lr 1.000000e-03 rs 0.250000 bs 200 ni 1000 hs 75 train accuracy: 0.485163 val accuracy: 0.469000
# lr 1.000000e-03 rs 0.250000 bs 200 ni 1000 hs 100 train accuracy: 0.499102 val accuracy: 0.479000
# lr 1.000000e-03 rs 0.250000 bs 200 ni 1500 hs 50 train accuracy: 0.510612 val accuracy: 0.477000
# lr 1.000000e-03 rs 0.250000 bs 200 ni 1500 hs 75 train accuracy: 0.524082 val accuracy: 0.511000
# lr 1.000000e-03 rs 0.250000 bs 200 ni 1500 hs 100 train accuracy: 0.528918 val accuracy: 0.501000
# lr 1.000000e-03 rs 0.250000 bs 200 ni 2000 hs 50 train accuracy: 0.524041 val accuracy: 0.497000
# lr 1.000000e-03 rs 0.250000 bs 200 ni 2000 hs 75 train accuracy: 0.531286 val accuracy: 0.513000
# lr 1.000000e-03 rs 0.250000 bs 200 ni 2000 hs 100 train accuracy: 0.550796 val accuracy: 0.500000
# lr 1.000000e-03 rs 0.250000 bs 300 ni 1000 hs 50 train accuracy: 0.484306 val accuracy: 0.449000
# lr 1.000000e-03 rs 0.250000 bs 300 ni 1000 hs 75 train accuracy: 0.504878 val accuracy: 0.476000
# lr 1.000000e-03 rs 0.250000 bs 300 ni 1000 hs 100 train accuracy: 0.509061 val accuracy: 0.488000
# lr 1.000000e-03 rs 0.250000 bs 300 ni 1500 hs 50 train accuracy: 0.519980 val accuracy: 0.491000
# lr 1.000000e-03 rs 0.250000 bs 300 ni 1500 hs 75 train accuracy: 0.518796 val accuracy: 0.510000
# lr 1.000000e-03 rs 0.250000 bs 300 ni 1500 hs 100 train accuracy: 0.537714 val accuracy: 0.488000
# lr 1.000000e-03 rs 0.250000 bs 300 ni 2000 hs 50 train accuracy: 0.531735 val accuracy: 0.509000
# lr 1.000000e-03 rs 0.250000 bs 300 ni 2000 hs 75 train accuracy: 0.531959 val accuracy: 0.481000
# lr 1.000000e-03 rs 0.250000 bs 300 ni 2000 hs 100 train accuracy: 0.536000 val accuracy: 0.502000
# lr 1.000000e-03 rs 0.250000 bs 400 ni 1000 hs 50 train accuracy: 0.495551 val accuracy: 0.493000
# lr 1.000000e-03 rs 0.250000 bs 400 ni 1000 hs 75 train accuracy: 0.502878 val accuracy: 0.479000
# lr 1.000000e-03 rs 0.250000 bs 400 ni 1000 hs 100 train accuracy: 0.509122 val accuracy: 0.483000
# lr 1.000000e-03 rs 0.250000 bs 400 ni 1500 hs 50 train accuracy: 0.521980 val accuracy: 0.492000
# lr 1.000000e-03 rs 0.250000 bs 400 ni 1500 hs 75 train accuracy: 0.529755 val accuracy: 0.498000
# lr 1.000000e-03 rs 0.250000 bs 400 ni 1500 hs 100 train accuracy: 0.539816 val accuracy: 0.490000
# lr 1.000000e-03 rs 0.250000 bs 400 ni 2000 hs 50 train accuracy: 0.534571 val accuracy: 0.497000
# lr 1.000000e-03 rs 0.250000 bs 400 ni 2000 hs 75 train accuracy: 0.553408 val accuracy: 0.511000
# lr 1.000000e-03 rs 0.250000 bs 400 ni 2000 hs 100 train accuracy: 0.567143 val accuracy: 0.525000
# lr 1.000000e-03 rs 0.500000 bs 200 ni 1000 hs 50 train accuracy: 0.480388 val accuracy: 0.472000
# lr 1.000000e-03 rs 0.500000 bs 200 ni 1000 hs 75 train accuracy: 0.490184 val accuracy: 0.488000
# lr 1.000000e-03 rs 0.500000 bs 200 ni 1000 hs 100 train accuracy: 0.495082 val accuracy: 0.470000
# lr 1.000000e-03 rs 0.500000 bs 200 ni 1500 hs 50 train accuracy: 0.497837 val accuracy: 0.482000
# lr 1.000000e-03 rs 0.500000 bs 200 ni 1500 hs 75 train accuracy: 0.513265 val accuracy: 0.474000
# lr 1.000000e-03 rs 0.500000 bs 200 ni 1500 hs 100 train accuracy: 0.519020 val accuracy: 0.505000
# lr 1.000000e-03 rs 0.500000 bs 200 ni 2000 hs 50 train accuracy: 0.506265 val accuracy: 0.479000
# lr 1.000000e-03 rs 0.500000 bs 200 ni 2000 hs 75 train accuracy: 0.519592 val accuracy: 0.489000
# lr 1.000000e-03 rs 0.500000 bs 200 ni 2000 hs 100 train accuracy: 0.523571 val accuracy: 0.486000
# lr 1.000000e-03 rs 0.500000 bs 300 ni 1000 hs 50 train accuracy: 0.487122 val accuracy: 0.474000
# lr 1.000000e-03 rs 0.500000 bs 300 ni 1000 hs 75 train accuracy: 0.496918 val accuracy: 0.472000
# lr 1.000000e-03 rs 0.500000 bs 300 ni 1000 hs 100 train accuracy: 0.494204 val accuracy: 0.472000
# lr 1.000000e-03 rs 0.500000 bs 300 ni 1500 hs 50 train accuracy: 0.508694 val accuracy: 0.478000
# lr 1.000000e-03 rs 0.500000 bs 300 ni 1500 hs 75 train accuracy: 0.523184 val accuracy: 0.504000
# lr 1.000000e-03 rs 0.500000 bs 300 ni 1500 hs 100 train accuracy: 0.512796 val accuracy: 0.481000
# lr 1.000000e-03 rs 0.500000 bs 300 ni 2000 hs 50 train accuracy: 0.514551 val accuracy: 0.496000
# lr 1.000000e-03 rs 0.500000 bs 300 ni 2000 hs 75 train accuracy: 0.532469 val accuracy: 0.495000
# lr 1.000000e-03 rs 0.500000 bs 300 ni 2000 hs 100 train accuracy: 0.541959 val accuracy: 0.501000
# lr 1.000000e-03 rs 0.500000 bs 400 ni 1000 hs 50 train accuracy: 0.488347 val accuracy: 0.465000
# lr 1.000000e-03 rs 0.500000 bs 400 ni 1000 hs 75 train accuracy: 0.492837 val accuracy: 0.481000
# lr 1.000000e-03 rs 0.500000 bs 400 ni 1000 hs 100 train accuracy: 0.499816 val accuracy: 0.475000
# lr 1.000000e-03 rs 0.500000 bs 400 ni 1500 hs 50 train accuracy: 0.512327 val accuracy: 0.477000
# lr 1.000000e-03 rs 0.500000 bs 400 ni 1500 hs 75 train accuracy: 0.520122 val accuracy: 0.494000
# lr 1.000000e-03 rs 0.500000 bs 400 ni 1500 hs 100 train accuracy: 0.530102 val accuracy: 0.481000
# lr 1.000000e-03 rs 0.500000 bs 400 ni 2000 hs 50 train accuracy: 0.521347 val accuracy: 0.491000
# lr 1.000000e-03 rs 0.500000 bs 400 ni 2000 hs 75 train accuracy: 0.541796 val accuracy: 0.499000
# lr 1.000000e-03 rs 0.500000 bs 400 ni 2000 hs 100 train accuracy: 0.543061 val accuracy: 0.481000
# lr 1.500000e-03 rs 0.175000 bs 200 ni 1000 hs 50 train accuracy: 0.499408 val accuracy: 0.470000
# lr 1.500000e-03 rs 0.175000 bs 200 ni 1000 hs 75 train accuracy: 0.505408 val accuracy: 0.492000
# lr 1.500000e-03 rs 0.175000 bs 200 ni 1000 hs 100 train accuracy: 0.509755 val accuracy: 0.480000
# lr 1.500000e-03 rs 0.175000 bs 200 ni 1500 hs 50 train accuracy: 0.510367 val accuracy: 0.485000
# lr 1.500000e-03 rs 0.175000 bs 200 ni 1500 hs 75 train accuracy: 0.534061 val accuracy: 0.498000
# lr 1.500000e-03 rs 0.175000 bs 200 ni 1500 hs 100 train accuracy: 0.542918 val accuracy: 0.500000
# lr 1.500000e-03 rs 0.175000 bs 200 ni 2000 hs 50 train accuracy: 0.527061 val accuracy: 0.509000
# lr 1.500000e-03 rs 0.175000 bs 200 ni 2000 hs 75 train accuracy: 0.551347 val accuracy: 0.498000
# lr 1.500000e-03 rs 0.175000 bs 200 ni 2000 hs 100 train accuracy: 0.555327 val accuracy: 0.511000
# lr 1.500000e-03 rs 0.175000 bs 300 ni 1000 hs 50 train accuracy: 0.508163 val accuracy: 0.499000
# lr 1.500000e-03 rs 0.175000 bs 300 ni 1000 hs 75 train accuracy: 0.514673 val accuracy: 0.478000
# lr 1.500000e-03 rs 0.175000 bs 300 ni 1000 hs 100 train accuracy: 0.485265 val accuracy: 0.467000
# lr 1.500000e-03 rs 0.175000 bs 300 ni 1500 hs 50 train accuracy: 0.505265 val accuracy: 0.482000
# lr 1.500000e-03 rs 0.175000 bs 300 ni 1500 hs 75 train accuracy: 0.525388 val accuracy: 0.476000
# lr 1.500000e-03 rs 0.175000 bs 300 ni 1500 hs 100 train accuracy: 0.546020 val accuracy: 0.500000
# lr 1.500000e-03 rs 0.175000 bs 300 ni 2000 hs 50 train accuracy: 0.528367 val accuracy: 0.490000
# lr 1.500000e-03 rs 0.175000 bs 300 ni 2000 hs 75 train accuracy: 0.539224 val accuracy: 0.496000
# lr 1.500000e-03 rs 0.175000 bs 300 ni 2000 hs 100 train accuracy: 0.564959 val accuracy: 0.504000
# lr 1.500000e-03 rs 0.175000 bs 400 ni 1000 hs 50 train accuracy: 0.510776 val accuracy: 0.474000
# lr 1.500000e-03 rs 0.175000 bs 400 ni 1000 hs 75 train accuracy: 0.518449 val accuracy: 0.478000
# lr 1.500000e-03 rs 0.175000 bs 400 ni 1000 hs 100 train accuracy: 0.522531 val accuracy: 0.472000
# lr 1.500000e-03 rs 0.175000 bs 400 ni 1500 hs 50 train accuracy: 0.540633 val accuracy: 0.496000
# lr 1.500000e-03 rs 0.175000 bs 400 ni 1500 hs 75 train accuracy: 0.517551 val accuracy: 0.472000
# lr 1.500000e-03 rs 0.175000 bs 400 ni 1500 hs 100 train accuracy: 0.570102 val accuracy: 0.530000
# lr 1.500000e-03 rs 0.175000 bs 400 ni 2000 hs 50 train accuracy: 0.550592 val accuracy: 0.517000
# lr 1.500000e-03 rs 0.175000 bs 400 ni 2000 hs 75 train accuracy: 0.572878 val accuracy: 0.511000
# lr 1.500000e-03 rs 0.175000 bs 400 ni 2000 hs 100 train accuracy: 0.569510 val accuracy: 0.515000
# lr 1.500000e-03 rs 0.250000 bs 200 ni 1000 hs 50 train accuracy: 0.497102 val accuracy: 0.474000
# lr 1.500000e-03 rs 0.250000 bs 200 ni 1000 hs 75 train accuracy: 0.510612 val accuracy: 0.475000
# lr 1.500000e-03 rs 0.250000 bs 200 ni 1000 hs 100 train accuracy: 0.503388 val accuracy: 0.484000
# lr 1.500000e-03 rs 0.250000 bs 200 ni 1500 hs 50 train accuracy: 0.505551 val accuracy: 0.488000
# lr 1.500000e-03 rs 0.250000 bs 200 ni 1500 hs 75 train accuracy: 0.526510 val accuracy: 0.482000
# lr 1.500000e-03 rs 0.250000 bs 200 ni 1500 hs 100 train accuracy: 0.528408 val accuracy: 0.510000
# lr 1.500000e-03 rs 0.250000 bs 200 ni 2000 hs 50 train accuracy: 0.533816 val accuracy: 0.498000
# lr 1.500000e-03 rs 0.250000 bs 200 ni 2000 hs 75 train accuracy: 0.542939 val accuracy: 0.497000
# lr 1.500000e-03 rs 0.250000 bs 200 ni 2000 hs 100 train accuracy: 0.556122 val accuracy: 0.491000
# lr 1.500000e-03 rs 0.250000 bs 300 ni 1000 hs 50 train accuracy: 0.507551 val accuracy: 0.472000
# lr 1.500000e-03 rs 0.250000 bs 300 ni 1000 hs 75 train accuracy: 0.503469 val accuracy: 0.501000
# lr 1.500000e-03 rs 0.250000 bs 300 ni 1000 hs 100 train accuracy: 0.510184 val accuracy: 0.491000
# lr 1.500000e-03 rs 0.250000 bs 300 ni 1500 hs 50 train accuracy: 0.495673 val accuracy: 0.466000
# lr 1.500000e-03 rs 0.250000 bs 300 ni 1500 hs 75 train accuracy: 0.533184 val accuracy: 0.501000
# lr 1.500000e-03 rs 0.250000 bs 300 ni 1500 hs 100 train accuracy: 0.525122 val accuracy: 0.497000
# lr 1.500000e-03 rs 0.250000 bs 300 ni 2000 hs 50 train accuracy: 0.528796 val accuracy: 0.486000
# lr 1.500000e-03 rs 0.250000 bs 300 ni 2000 hs 75 train accuracy: 0.546429 val accuracy: 0.499000
# lr 1.500000e-03 rs 0.250000 bs 300 ni 2000 hs 100 train accuracy: 0.540939 val accuracy: 0.503000
# lr 1.500000e-03 rs 0.250000 bs 400 ni 1000 hs 50 train accuracy: 0.512490 val accuracy: 0.488000
# lr 1.500000e-03 rs 0.250000 bs 400 ni 1000 hs 75 train accuracy: 0.527673 val accuracy: 0.500000
# lr 1.500000e-03 rs 0.250000 bs 400 ni 1000 hs 100 train accuracy: 0.533571 val accuracy: 0.485000
# lr 1.500000e-03 rs 0.250000 bs 400 ni 1500 hs 50 train accuracy: 0.534143 val accuracy: 0.504000
# lr 1.500000e-03 rs 0.250000 bs 400 ni 1500 hs 75 train accuracy: 0.550082 val accuracy: 0.492000
# lr 1.500000e-03 rs 0.250000 bs 400 ni 1500 hs 100 train accuracy: 0.563163 val accuracy: 0.507000
# lr 1.500000e-03 rs 0.250000 bs 400 ni 2000 hs 50 train accuracy: 0.547020 val accuracy: 0.521000
# lr 1.500000e-03 rs 0.250000 bs 400 ni 2000 hs 75 train accuracy: 0.570633 val accuracy: 0.521000
# lr 1.500000e-03 rs 0.250000 bs 400 ni 2000 hs 100 train accuracy: 0.579020 val accuracy: 0.536000
# lr 1.500000e-03 rs 0.500000 bs 200 ni 1000 hs 50 train accuracy: 0.476939 val accuracy: 0.460000
# lr 1.500000e-03 rs 0.500000 bs 200 ni 1000 hs 75 train accuracy: 0.478571 val accuracy: 0.476000
# lr 1.500000e-03 rs 0.500000 bs 200 ni 1000 hs 100 train accuracy: 0.499755 val accuracy: 0.485000
# lr 1.500000e-03 rs 0.500000 bs 200 ni 1500 hs 50 train accuracy: 0.504776 val accuracy: 0.482000
# lr 1.500000e-03 rs 0.500000 bs 200 ni 1500 hs 75 train accuracy: 0.512857 val accuracy: 0.487000
# lr 1.500000e-03 rs 0.500000 bs 200 ni 1500 hs 100 train accuracy: 0.523122 val accuracy: 0.494000
# lr 1.500000e-03 rs 0.500000 bs 200 ni 2000 hs 50 train accuracy: 0.515735 val accuracy: 0.477000
# lr 1.500000e-03 rs 0.500000 bs 200 ni 2000 hs 75 train accuracy: 0.527755 val accuracy: 0.482000
# lr 1.500000e-03 rs 0.500000 bs 200 ni 2000 hs 100 train accuracy: 0.526755 val accuracy: 0.500000
# lr 1.500000e-03 rs 0.500000 bs 300 ni 1000 hs 50 train accuracy: 0.494224 val accuracy: 0.483000
# lr 1.500000e-03 rs 0.500000 bs 300 ni 1000 hs 75 train accuracy: 0.492408 val accuracy: 0.472000
# lr 1.500000e-03 rs 0.500000 bs 300 ni 1000 hs 100 train accuracy: 0.502918 val accuracy: 0.485000
# lr 1.500000e-03 rs 0.500000 bs 300 ni 1500 hs 50 train accuracy: 0.509816 val accuracy: 0.480000
# lr 1.500000e-03 rs 0.500000 bs 300 ni 1500 hs 75 train accuracy: 0.507857 val accuracy: 0.481000
# lr 1.500000e-03 rs 0.500000 bs 300 ni 1500 hs 100 train accuracy: 0.519898 val accuracy: 0.482000
# lr 1.500000e-03 rs 0.500000 bs 300 ni 2000 hs 50 train accuracy: 0.482469 val accuracy: 0.472000
# lr 1.500000e-03 rs 0.500000 bs 300 ni 2000 hs 75 train accuracy: 0.510286 val accuracy: 0.487000
# lr 1.500000e-03 rs 0.500000 bs 300 ni 2000 hs 100 train accuracy: 0.535857 val accuracy: 0.497000
# lr 1.500000e-03 rs 0.500000 bs 400 ni 1000 hs 50 train accuracy: 0.485122 val accuracy: 0.455000
# lr 1.500000e-03 rs 0.500000 bs 400 ni 1000 hs 75 train accuracy: 0.508755 val accuracy: 0.498000
# lr 1.500000e-03 rs 0.500000 bs 400 ni 1000 hs 100 train accuracy: 0.514408 val accuracy: 0.490000
# lr 1.500000e-03 rs 0.500000 bs 400 ni 1500 hs 50 train accuracy: 0.510735 val accuracy: 0.475000
# lr 1.500000e-03 rs 0.500000 bs 400 ni 1500 hs 75 train accuracy: 0.536082 val accuracy: 0.519000
# lr 1.500000e-03 rs 0.500000 bs 400 ni 1500 hs 100 train accuracy: 0.535388 val accuracy: 0.499000
# lr 1.500000e-03 rs 0.500000 bs 400 ni 2000 hs 50 train accuracy: 0.519327 val accuracy: 0.488000
# lr 1.500000e-03 rs 0.500000 bs 400 ni 2000 hs 75 train accuracy: 0.543469 val accuracy: 0.503000
# lr 1.500000e-03 rs 0.500000 bs 400 ni 2000 hs 100 train accuracy: 0.543796 val accuracy: 0.504000
# best validation accuracy achieved during cross-validation: 0.536000

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.52
